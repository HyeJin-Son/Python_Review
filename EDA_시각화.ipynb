# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
# %matplotlib inline
warnings.filterwarnings(action='ignore')

# %%
from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all"

# %%
import matplotlib.font_manager as fm  # 폰트확인 
font_list = [font.name for font in fm.fontManager.ttflist] # 설치된 폰트 확인 
font_list
plt.rcParams['font.family'] = 'Malgun Gothic' #폰트 변경
# Out:
# ['STIXSizeTwoSym',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'DejaVu Sans',
#  'cmex10',
#  'STIXSizeFourSym',
#  'DejaVu Sans Mono',
#  'cmr10',
#  'DejaVu Sans',
#  'cmss10',
#  'DejaVu Sans Mono',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'cmsy10',
#  'STIXSizeFiveSym',
#  'STIXGeneral',
#  'STIXNonUnicode',
#  'cmmi10',
#  'STIXSizeThreeSym',
#  'STIXSizeFourSym',
#  'STIXSizeOneSym',
#  'STIXSizeTwoSym',
#  'DejaVu Sans',
#  'STIXSizeOneSym',
#  'DejaVu Serif Display',
#  'STIXGeneral',
#  'cmb10',
#  'DejaVu Sans',
#  'STIXSizeThreeSym',
#  'DejaVu Sans Display',
#  'DejaVu Serif',
#  'STIXGeneral',
#  'DejaVu Serif',
#  'STIXNonUnicode',
#  'DejaVu Sans Mono',
#  'DejaVu Serif',
#  'cmtt10',
#  'Courier New',
#  'Verdana',
#  'Cambria',
#  'Microsoft YaHei',
#  'Arial',
#  'Mongolian Baiti',
#  'Times New Roman',
#  'Consolas',
#  'Palatino Linotype',
#  'Calibri',
#  'Constantia',
#  'Microsoft YaHei',
#  'Georgia',
#  'Microsoft Himalaya',
#  'SimSun',
#  'Segoe UI',
#  'Nirmala UI',
#  'Constantia',
#  'Yu Gothic',
#  'Impact',
#  'Georgia',
#  'Cambria',
#  'Leelawadee UI',
#  'Sitka Small',
#  'Candara',
#  'Corbel',
#  'Cambria',
#  'Segoe UI',
#  'Leelawadee UI',
#  'Microsoft Yi Baiti',
#  'Yu Gothic',
#  'Malgun Gothic',
#  'Segoe UI',
#  'Segoe UI',
#  'Tahoma',
#  'Constantia',
#  'Times New Roman',
#  'Ebrima',
#  'Candara',
#  'Calibri',
#  'Symbol',
#  'Verdana',
#  'Ebrima',
#  'Nirmala UI',
#  'Courier New',
#  'Arial',
#  'Segoe UI',
#  'Verdana',
#  'Candara',
#  'Corbel',
#  'Myanmar Text',
#  'Trebuchet MS',
#  'Candara',
#  'Courier New',
#  'Candara',
#  'Microsoft Sans Serif',
#  'Segoe Print',
#  'Calibri',
#  'MV Boli',
#  'Gabriola',
#  'Microsoft Tai Le',
#  'Georgia',
#  'Calibri',
#  'Microsoft JhengHei',
#  'Microsoft JhengHei',
#  'Segoe UI Emoji',
#  'Sitka Small',
#  'Microsoft JhengHei',
#  'Palatino Linotype',
#  'Segoe Script',
#  'Microsoft JhengHei',
#  'Times New Roman',
#  'Calibri',
#  'Segoe MDL2 Assets',
#  'Segoe UI Historic',
#  'Gulim',
#  'Segoe UI',
#  'SimSun',
#  'Javanese Text',
#  'Ebrima',
#  'Sitka Small',
#  'Segoe UI',
#  'Comic Sans MS',
#  'Myanmar Text',
#  'Courier New',
#  'Microsoft Sans Serif',
#  'Segoe UI',
#  'Constantia',
#  'Segoe UI Emoji',
#  'Yu Gothic',
#  'Comic Sans MS',
#  'HoloLens MDL2 Assets',
#  'Trebuchet MS',
#  'Segoe UI Symbol',
#  'Bahnschrift',
#  'Trebuchet MS',
#  'Comic Sans MS',
#  'Comic Sans MS',
#  'Calibri',
#  'Candara',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Webdings',
#  'Georgia',
#  'Microsoft Tai Le',
#  'Yu Gothic',
#  'Segoe UI',
#  'Marlett',
#  'Palatino Linotype',
#  'Segoe Print',
#  'Microsoft YaHei',
#  'Georgia',
#  'Microsoft PhagsPa',
#  'Courier New',
#  'Franklin Gothic Medium',
#  'MingLiU-ExtB',
#  'Times New Roman',
#  'Georgia',
#  'Microsoft PhagsPa',
#  'Tahoma',
#  'Microsoft New Tai Lue',
#  'Sitka Small',
#  'Microsoft YaHei',
#  'Batang',
#  'Malgun Gothic',
#  'Lucida Sans Unicode',
#  'Myanmar Text',
#  'Times New Roman',
#  'Microsoft JhengHei',
#  'Microsoft Yi Baiti',
#  'Consolas',
#  'Comic Sans MS',
#  'Corbel',
#  'Microsoft YaHei',
#  'Courier New',
#  'Segoe UI',
#  'Verdana',
#  'Constantia',
#  'Arial',
#  'Leelawadee UI',
#  'Sylfaen',
#  'Candara',
#  'Segoe UI',
#  'SimSun-ExtB',
#  'Candara',
#  'Corbel',
#  'Verdana',
#  'Palatino Linotype',
#  'Corbel',
#  'Segoe UI',
#  'Georgia',
#  'Cambria',
#  'Microsoft New Tai Lue',
#  'Courier New',
#  'Gadugi',
#  'Gabriola',
#  'Segoe Script',
#  'Trebuchet MS',
#  'Georgia',
#  'MV Boli',
#  'Verdana',
#  'Candara',
#  'Corbel',
#  'Microsoft New Tai Lue',
#  'Tahoma',
#  'Yu Gothic',
#  'Franklin Gothic Medium',
#  'Segoe Script',
#  'Gadugi',
#  'Trebuchet MS',
#  'Arial',
#  'Nirmala UI',
#  'Franklin Gothic Medium',
#  'Segoe UI',
#  'Malgun Gothic',
#  'Candara',
#  'Lucida Console',
#  'Microsoft PhagsPa',
#  'Cambria',
#  'Consolas',
#  'Verdana',
#  'Calibri',
#  'Nirmala UI',
#  'Segoe UI',
#  'Cambria',
#  'Segoe UI',
#  'Corbel',
#  'Consolas',
#  'Sylfaen',
#  'Segoe MDL2 Assets',
#  'Sitka Small',
#  'Malgun Gothic',
#  'Courier New',
#  'Ebrima',
#  'Segoe UI',
#  'Leelawadee UI',
#  'MingLiU-ExtB',
#  'Lucida Sans Unicode',
#  'Wingdings',
#  'Yu Gothic',
#  'Arial',
#  'Nirmala UI',
#  'Gulim',
#  'Arial',
#  'Segoe UI',
#  'Bahnschrift',
#  'Palatino Linotype',
#  'Segoe UI',
#  'Cambria',
#  'Consolas',
#  'Franklin Gothic Medium',
#  'Yu Gothic',
#  'Ink Free',
#  'Microsoft Himalaya',
#  'Batang',
#  'Segoe Print',
#  'Webdings',
#  'Constantia',
#  'Arial',
#  'Sitka Small',
#  'Comic Sans MS',
#  'Microsoft JhengHei',
#  'Mongolian Baiti',
#  'Segoe UI Historic',
#  'Microsoft Tai Le',
#  'Corbel',
#  'Segoe UI Symbol',
#  'Verdana',
#  'Gadugi',
#  'Constantia',
#  'Gadugi',
#  'Palatino Linotype',
#  'Trebuchet MS',
#  'Arial',
#  'Nirmala UI',
#  'Segoe Script',
#  'Segoe UI',
#  'Sitka Small',
#  'Comic Sans MS',
#  'Segoe UI',
#  'Javanese Text',
#  'Symbol',
#  'Microsoft Tai Le',
#  'Times New Roman',
#  'Consolas',
#  'HoloLens MDL2 Assets',
#  'Corbel',
#  'Ink Free',
#  'Corbel',
#  'Segoe UI',
#  'Lucida Console',
#  'SimSun-ExtB',
#  'Trebuchet MS',
#  'Segoe UI',
#  'Times New Roman',
#  'Impact',
#  'Leelawadee UI',
#  'Calibri',
#  'Tahoma',
#  'Sitka Small',
#  'Calibri',
#  'Times New Roman',
#  'Calibri',
#  'Microsoft PhagsPa',
#  'Candara',
#  'Constantia',
#  'Consolas',
#  'Arial',
#  'Cambria',
#  'Candara',
#  'Malgun Gothic',
#  'Arial',
#  'Corbel',
#  'Myanmar Text',
#  'Consolas',
#  'Segoe UI',
#  'MS Gothic',
#  'Microsoft YaHei',
#  'Palatino Linotype',
#  'Trebuchet MS',
#  'Segoe Print',
#  'Microsoft New Tai Lue',
#  'Yu Gothic',
#  'Calibri',
#  'MS Gothic',
#  'Palatino Linotype',
#  'Leelawadee UI',
#  'Corbel',
#  'Calibri',
#  'Wingdings',
#  'Malgun Gothic']

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
titanic.describe()#널값이 있응 시리즈는 통계 연산 불가능
titanic
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.isnull().sum() #데이터 프레임의 널 값의 sum확인
#titanic.isnull().value_counts()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
#2.결측데이터
def  결측_table(df): 
        null_val = df.isnull().sum()
        percent = 100 * df.isnull().sum()/len(df)
        res= pd.concat([null_val, percent], axis=1)#두개의 시리즈를 병합
        res_table_ren_columns = res.rename(
        columns = {0 : '결측값', 1 : '%'})
        return res_table_ren_columns
결측_table(titanic)
# Out:
#              결측값          %
# survived       0   0.000000
# pclass         0   0.000000
# sex            0   0.000000
# age          177  19.865320
# sibsp          0   0.000000
# parch          0   0.000000
# fare           0   0.000000
# embarked       2   0.224467
# class          0   0.000000
# who            0   0.000000
# adult_male     0   0.000000
# deck         688  77.216611
# embark_town    2   0.224467
# alive          0   0.000000
# alone          0   0.000000

# %%
#3 Seaborn 카운트플롯 sns.countplot: 카테고리 데이터 정보확인
cols = ['survived', 'sex', 'pclass', 'sibsp', 'parch', 'embarked']
nr_rows = 2
nr_cols = 3

fig, axs = plt.subplots(nr_rows, nr_cols, figsize=(nr_cols*3.5,nr_rows*3))

for r in range(0,nr_rows):
    for c in range(0,nr_cols):  
        i = r*nr_cols+c       
        ax = axs[r][c]
        sns.countplot(titanic[cols[i]], hue=titanic["survived"], ax=ax)
        ax.set_title(cols[i], fontsize=14, fontweight='bold')
        ax.legend(title="survived", loc='upper center') 

plt.tight_layout()

# %% [raw]
#     #3의 결과를 확인하고 그래프로 데이터를 확인해보자.
# 1) 남성보다 여성이 생존할 확률이 높다. -> 여성이나 아이가 먼저 대피하지 않았을까?
# 2) pclass가 높으면 생존할 확률이 높다 -> 부자면 먼저 생존하나?
# 3) 가족이 없는 사람이 생존률이 낮을까?->parch 0인 사람의 생존률이 높다, 가족이 없는 사람보다 생존률이 높다.(서로 협력으로 대피)
# 4)c,q항구에서 타는 사람들 쪽이 s 항구에서 타는 사람보다 생존률이 낮다?

# %%
#4 Seaborn Distplots:분산정보 sns.distplot/성별,pclass, survived 에 대한 age 에 대한 분산정보
bins = np.arange(0, 80, 5)
g = sns.FacetGrid(titanic, row='sex', col='pclass', hue='survived', margin_titles=True, size=3, aspect=1.1)
g.map(sns.distplot, 'age', kde=False, bins=bins, hist_kws=dict(alpha=0.6))
g.add_legend()  
plt.show()

# %%
bins = np.arange(0, 80, 5)
g = sns.FacetGrid(titanic, col='sex', hue='survived', margin_titles=True, height=6, aspect=1.0)
g.map(sns.distplot, 'age', kde=True, bins=bins, hist=False)
g.add_legend()  
plt.show()

# %% [raw]
# 1)남성은 pclass가 1일때 또는 5세이하일 떄 생존확률이 높다.
# 2) 여성 생존확률이 가장 앉은 것은 pclass 3에서 40~60이면 40세 이상일때 이다.
# 3) pclass 3에서 대부분의 승객은 남성이며 20~40(15~30)정도 범위에 있다.
# 4)전체적으로 15~30세 정도의 남성의 생존률이 낮다

# %%
#배운임의 분산을 확인하자

titanic['fare'].max()
#output: 512.3292
bins = np.arange(0, 550, 50)
g = sns.FacetGrid(titanic, row='sex', col='pclass', hue='survived', margin_titles=True, height=3, aspect=2.0)
g.map(sns.distplot, 'fare', kde=False, bins=bins,hist_kws=dict(alpha=0.6))
g.add_legend()  
plt.show()

# %%
#5. 막대그래프 : 카테고리별 평균값, 신뢰구간 플로팅 -> PClass가 높을 수록 생존률이 높다.
sns.barplot(x='pclass', y='survived', data=titanic);
plt.ylabel("Survival Rate")
plt.title("Survival as function of Pclass")
plt.show()

# %%
#남여별로 분석해보자  #p1 클래스 여성으로 0.90%이상 살아남음/p3 클래스의 남성은 생존률이 낮다.
sns.barplot(x='sex', y='survived', hue='pclass', data=titanic)
plt.ylabel("Survival Rate")
plt.title("Survival as function of Pclass and Sex")
plt.show()

# %%
#각 항구의 생존률
sns.barplot(x='embarked', y='survived', hue='pclass', data=titanic)
plt.ylabel("Survival Rate")
plt.title("각 항구에 대한 Survival rate")
plt.show()

# %%
#Q의 신뢰 구간이 모호하다 할 경우, 각 항구에서 승객수를 출력하자
sns.countplot(x='embarked', hue='pclass', data=titanic)
plt.title("항구에서의 승객수")
plt.show()
#s항에서 탑승한 승객이 p1 클래스의 비율보다 낮다.
#q3 pclass3의 승객이 거의 이다.

# %%
#6) boxplot:중앙값, 이상값 분산정보등 시각화 / 각 항구, 나이에 관한 값
#사분위수 나타내는 시각화
#https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html
#https://en.wikipedia.org/wiki/Box_plot
sns.boxplot(x='embarked', y='age', data=titanic)
plt.title("각 항구에 대한 나이")
plt.show()

# %%
titanic['age'].quantile([.0,.2,.4,.6,.8,1.0])#데이터의 백분위수, 시리즈메소드
#[0.42 19.00]<[19.0 25.0]<[25.0  31.80]<[31.80  41.00]<[41.0 80.0]         ....]라벨링 분할
# 'child'       'young'      'middle'        'old'       'very old'
# Out:
# 0.0     0.42
# 0.2    19.00
# 0.4    25.00
# 0.6    31.80
# 0.8    41.00
# 1.0    80.00
# Name: age, dtype: float64

# %%
titanic['age'].plot.box()
# Out:
# <AxesSubplot:>

# %%
IQR=Q3-Q1
최대값 _극단치 경계=Q3+Q1*1.5
최소값 _극단치 경계=Q1-Q1*1.5

# %%
#'age'로 등급별 생존률 구하기, 1-1 피벗과 통계 함수를 확인
titanic.pivot_table('survived','age',aggfunc='mean')
titanic['age'].min()
titanic['age'].max()
titanic['age'].mean()
# Out:
#        survived
# age
# 0.42        1.0
# 0.67        1.0
# 0.75        1.0
# 0.83        1.0
# 0.92        1.0
# ...         ...
# 70.00       0.0
# 70.50       0.0
# 71.00       0.0
# 74.00       0.0
# 80.00       1.0
#
# [88 rows x 1 columns]
# 0.42
# 80.0
# 29.69911764705882

# %%
#1-2 라벨링 등급 나누기
titanic['age_class']=pd.qcut(titanic.age,5,labels=['child','young','middle'
                                                   ,'old','very old'])
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone age_class
# 0      man        True  NaN  Southampton    no  False     young
# 1    woman       False    C    Cherbourg   yes  False       old
# 2    woman       False  NaN  Southampton   yes   True    middle
# 3    woman       False    C  Southampton   yes  False       old
# 4      man        True  NaN  Southampton    no   True       old
# ..     ...         ...  ...          ...   ...    ...       ...
# 886    man        True  NaN  Southampton    no   True    middle
# 887  woman       False    B  Southampton   yes   True     child
# 888  woman       False  NaN  Southampton    no  False       NaN
# 889    man        True    C    Cherbourg   yes   True    middle
# 890    man        True  NaN   Queenstown    no   True       old
#
# [891 rows x 16 columns]

# %%
#1-3
titanic.pivot_table('survived','age_class',aggfunc='mean')
# Out:
#            survived
# age_class
# child      0.481707
# young      0.328467
# middle     0.393701
# old        0.437500
# very old   0.373239

# %%
#1-4'sex','age_class'를 MultiIndex로 한 평균 생존율
titanic.pivot_table('survived',index=['sex','age_class'],aggfunc='mean')
# Out:
#                   survived
# sex    age_class
# female child      0.706667
#        young      0.723404
#        middle     0.727273
#        old        0.843137
#        very old   0.795455
# male   child      0.292135
#        young      0.122222
#        middle     0.216867
#        old        0.215054
#        very old   0.183673

# %%
#분포의 갯수 1-5
titanic['age_class'].value_counts()
# Out:
# child       164
# old         144
# very old    142
# young       137
# middle      127
# Name: age_class, dtype: int64

# %%
#생존율의 분포 1-6
titanic['survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: survived, dtype: int64

# %%
# Series 객체의 quantile() 함수: 데이터의 백분위수
titanic['age'].quantile([.0,.2,.4,.6,.8,1.0])
# Out:
# 0.0     0.42
# 0.2    19.00
# 0.4    25.00
# 0.6    31.80
# 0.8    41.00
# 1.0    80.00
# Name: age, dtype: float64

# %%
#choose color
cm_surv = ["darkgrey" , "lightgreen"]

#plot swarm
fig, ax = plt.subplots(figsize=(13,7))
sns.swarmplot(x='pclass', y='age', hue='survived', split=True, data=titanic , palette=cm_surv, size=7, ax=ax)
plt.title('Survivals for Age and Pclass ')
plt.show()

#plot violin
fig, ax = plt.subplots(figsize=(13,7))
sns.violinplot(x="pclass", y="age", hue='survived', data=titanic, split=True, bw=0.05 , palette=cm_surv, ax=ax)
plt.title('Survivals for Age and Pclass ')
plt.show()
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>
# Text(0.5, 1.0, 'Survivals for Age and Pclass ')
# <AxesSubplot:xlabel='pclass', ylabel='age'>
# Text(0.5, 1.0, 'Survivals for Age and Pclass ')

# %% [raw]
# https://scikit-learn.org/stable/modules/preprocessing.html#preprocessing

# %% [raw]
# https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html#sphx-glr-auto-examples-classification-plot-classifier-comparison-py
