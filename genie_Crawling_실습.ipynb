# %%
#지니 사이트에 접속하기
from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome('C:\Myexam\chromedriver/chromedriver.exe')
url='http://www.genie.co.kr/chart/top200'
driver.get(url)

html=driver.page_source
soup=BeautifulSoup(html,'html.parser')
# Out:
# C:\Users\82105\AppData\Local\Temp\ipykernel_896\3915233754.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('C:\Myexam\chromedriver/chromedriver.exe')

# %% [raw]
# 분석
#
#  tbody > tr
#
#  순위 tbody>td.number
#  제목   a.title
#  가수   a.artist

# %%
#반복문을 이용해 곡과 가수명을 song_data에 저장하기

song_data=[]
songs=soup.select('tbody>tr')
for song in songs:
    rank = song.select('td.number')[0].text[0:1]
    title = song.select('a.title')[0].text.strip()
    singer = song.select('a.artist')[0].text
    song_data.append(['Genie',rank,title,singer])

# %%
#song_data 리스트를 이용해 엑셀 파일로 저장하기

import pandas as pd

columns=['서비스','순위','타이틀','가수']
pd_data=pd.DataFrame(song_data, columns=columns)
pd_data
# Out:
#       서비스 순위                                                타이틀  \
# 0   Genie  1                                              Ditto
# 1   Genie  2                                                OMG
# 2   Genie  3                                           Hype boy
# 3   Genie  4                                          사랑은 늘 도망가
# 4   Genie  5                                           우리들의 블루스
# 5   Genie  6                                            사건의 지평선
# 6   Genie  7                                        다시 만날 수 있을까
# 7   Genie  8                                         London Boy
# 8   Genie  9                                           Polaroid
# 9   Genie  1                                          이제 나만 믿어요
# 10  Genie  1                                                무지개
# 11  Genie  1                                                아버지
# 12  Genie  1                                          A bientot
# 13  Genie  1                                         손이 참 곱던 그대
# 14  Genie  1                                             사랑해 진짜
# 15  Genie  1                                               연애편지
# 16  Genie  1                                               인생찬가
# 17  Genie  1                                               보금자리
# 18  Genie  1                     친구로 지내다 보면 (Feat. 김민석 of 멜로망스)
# 19  Genie  2                                        ANTIFRAGILE
# 20  Genie  2                          VIBE (Feat. Jimin of BTS)
# 21  Genie  2                                    Sugar Rush Ride
# 22  Genie  2                                          Attention
# 23  Genie  2                                         After LIKE
# 24  Genie  2                                              Candy
# 25  Genie  2             NOT SORRY (Feat. pH-1) (Prod. by Slom)
# 26  Genie  2                      I Don't Think That I Like Her
# 27  Genie  2                                          LOVE DIVE
# 28  Genie  2                                Devil by the Window
# 29  Genie  3                                          네버랜드를 떠나며
# 30  Genie  3                                               Nxde
# 31  Genie  3                              Tinnitus (돌멩이가 되고 싶어)
# 32  Genie  3                      Happy Fools (Feat. Coi Leray)
# 33  Genie  3                     새삥 (Prod. by ZICO) (Feat. 호미들)
# 34  Genie  3                                         그중에 그대를 만나
# 35  Genie  3                                             당신을 만나
# 36  Genie  3                                             Cookie
# 37  Genie  3                                          Monologue
# 38  Genie  3                                     Say I Love You
# 39  Genie  4                                            나의 목소리로
# 40  Genie  4                                   That's Hilarious
# 41  Genie  4                    Rush Hour (Feat. j-hope of BTS)
# 42  Genie  4  Dreamers (Music from the FIFA World Cup Qatar ...
# 43  Genie  4                                          Shut Down
# 44  Genie  4                                  Good Boy Gone Bad
# 45  Genie  4                                             Unholy
# 46  Genie  4                                          해요 (2022)
# 47  Genie  4                                             사랑인가 봐
# 48  Genie  4                                                주마등
# 49  Genie  5                                              오르트구름
#
#                         가수
# 0                 NewJeans
# 1                 NewJeans
# 2                 NewJeans
# 3                      임영웅
# 4                      임영웅
# 5              윤하 (YOUNHA)
# 6                      임영웅
# 7                      임영웅
# 8                      임영웅
# 9                      임영웅
# 10                     임영웅
# 11                     임영웅
# 12                     임영웅
# 13                     임영웅
# 14                     임영웅
# 15                     임영웅
# 16                     임영웅
# 17                     임영웅
# 18       BIG Naughty (서동현)
# 19      LE SSERAFIM (르세라핌)
# 20                      태양
# 21               투모로우바이투게더
# 22                NewJeans
# 23               IVE (아이브)
# 24               NCT DREAM
# 25                     이영지
# 26            Charlie Puth
# 27               IVE (아이브)
# 28               투모로우바이투게더
# 29               투모로우바이투게더
# 30                 (여자)아이들
# 31               투모로우바이투게더
# 32               투모로우바이투게더
# 33               지코 (ZICO)
# 34                     김호중
# 35               김호중 & 송가인
# 36                NewJeans
# 37                테이 (Tei)
# 38              우디 (Woody)
# 39                     김호중
# 40            Charlie Puth
# 41                   Crush
# 42              정국 & 방탄소년단
# 43               BLACKPINK
# 44               투모로우바이투게더
# 45  Sam Smith & Kim Petras
# 46                     #안녕
# 47        멜로망스 (MeloMance)
# 48                     김호중
# 49             윤하 (YOUNHA)

# %%
pd_data.to_excel('C:/Myexam/genie.xlsx',index=False)
