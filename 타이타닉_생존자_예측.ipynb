# %% [markdown]
# <a href="https://colab.research.google.com/github/HyeJin-Son/Python_Review/blob/master/%ED%83%80%EC%9D%B4%ED%83%80%EB%8B%89_%EC%83%9D%EC%A1%B4%EC%9E%90_%EC%98%88%EC%B8%A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 데이터 전처리

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
titanic_df = pd.read_csv('/titanic_train.csv')
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# - passengerid : 탑승자 데이터 일련번호
# - survived : 생존여부, 0 = 사망, 1 = 생존
# - Pclass : 티켓의 선실 등급. 1 = 일등석, 2 = 이등석, 3 = 삼등석
# - name : 탑승자 이름
# - sex : 탐승자 성별
# - Age : 탐승자 나이
# - SibSp : 같이 탑승한 형제자매 또는 배우자 인원수
# - Parch : 같이 탑승한 부모님 또는 어린이 인원수
# - ticket : 티켓 번호
# - Fare : 요금
# - cabin : 선실 번호
# - embarked : 중간 정착 항구 C = Cherbourg, Q=Queenstown, S=Southampton

# %%
# null 값을 확인해보기 위함
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# - Null값 처리 .fillna()
#   - age : 평균값
#   - Cabin : N
#   - Embarked : N

# %%
titanic_df['Age'].fillna(titanic_df['Age'].mean(),inplace=True)
titanic_df['Cabin'].fillna('N',inplace=True)
titanic_df['Embarked'].fillna('N',inplace=True)

# %%
#널 값이 없어짐을 확인
print(titanic_df.isnull().sum())
print()
print(titanic_df.isnull().sum().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
#
# 0

# %%
#Cabin 컬럼 정리
#str로 문자열 읽어오기 가능
titanic_df['Cabin']=titanic_df['Cabin'].str[:1]
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
titanic_df['Age'].max()
# Out:
# 80.0

# %%
titanic_df['Age'].min()
# Out:
# 0.42

# %%
#apply 함수 사용

def ages(x):
  if x>=80:
    x=80
  elif x>=70:
    x=70
  elif x>=60:
    x=60
  elif x>=50:
    x=50
  elif x>=40:
    x=40
  elif x>=30:
    x=30
  elif x>=20:
    x=20
  elif x>=10:
    x=10
  else :
    x=1

  return x


titanic_df["Age's"]=titanic_df['Age'].apply(ages)

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %% [markdown]
# - 불필요한 속성제거
#   - PassengerId, Ticket, Name

# %%
titanic_df.drop(['PassengerId', 'Ticket', 'Name','Age'],inplace=True,axis=1)

# %%
titanic_df
# Out:
#      Survived  Pclass     Sex  SibSp  Parch     Fare Cabin Embarked  Age's
# 0           0       3    male      1      0   7.2500     N        S     20
# 1           1       1  female      1      0  71.2833   C85        C     30
# 2           1       3  female      0      0   7.9250     N        S     20
# 3           1       1  female      1      0  53.1000  C123        S     30
# 4           0       3    male      0      0   8.0500     N        S     30
# ..        ...     ...     ...    ...    ...      ...   ...      ...    ...
# 886         0       2    male      0      0  13.0000     N        S     20
# 887         1       1  female      0      0  30.0000   B42        S     10
# 888         0       3  female      1      2  23.4500     N        S     20
# 889         1       1    male      0      0  30.0000  C148        C     20
# 890         0       3    male      0      0   7.7500     N        Q     30
#
# [891 rows x 9 columns]

# %% [markdown]
# - 레이블 인코딩 수행
#   - 문자열 -> 숫자
#   - Sex, Cabin, Embarked

# %%
from sklearn.preprocessing import LabelEncoder
features = ['Cabin','Sex','Embarked']
for feature in features:
 le = LabelEncoder()
 le = le.fit(titanic_df[feature])
 titanic_df[feature] = le.transform(titanic_df[feature])
titanic_df
# Out:
#      Survived  Pclass  Sex  SibSp  Parch     Fare  Cabin  Embarked  Age's
# 0           0       3    1      1      0   7.2500    146         3     20
# 1           1       1    0      1      0  71.2833     81         0     30
# 2           1       3    0      0      0   7.9250    146         3     20
# 3           1       1    0      1      0  53.1000     55         3     30
# 4           0       3    1      0      0   8.0500    146         3     30
# ..        ...     ...  ...    ...    ...      ...    ...       ...    ...
# 886         0       2    1      0      0  13.0000    146         3     20
# 887         1       1    0      0      0  30.0000     30         3     10
# 888         0       3    0      1      2  23.4500    146         3     20
# 889         1       1    1      0      0  30.0000     60         0     20
# 890         0       3    1      0      0   7.7500    146         2     30
#
# [891 rows x 9 columns]

# %%
#feature와 Label로 나눔
y_titanic_df = titanic_df['Survived']
X_titanic_df= titanic_df.drop('Survived',axis=1)

# %%
#Train과 Test 나눔
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X_titanic_df, y_titanic_df, \
 test_size=0.2, random_state=11)

# %% [markdown]
# - DecisionTreeClassifier
# - RandomForestClassifier
# - LogisticRegression

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
# 결정트리, Random Forest, 로지스틱 회귀를 위한 사이킷런 Classifier 클래스 생성
dt_clf = DecisionTreeClassifier(random_state=11)
rf_clf = RandomForestClassifier(random_state=11)
lr_clf = LogisticRegression()
# DecisionTreeClassifier 학습/예측/평가
dt_clf.fit(X_train , y_train)
dt_pred = dt_clf.predict(X_test)
print('DecisionTreeClassifier 정확도: {0:.4f}'.format(accuracy_score(y_test, dt_pred)))
# RandomForestClassifier 학습/예측/평가
rf_clf.fit(X_train , y_train)
rf_pred = rf_clf.predict(X_test)
print('RandomForestClassifier 정확도:{0:.4f}'.format(accuracy_score(y_test, rf_pred)))
# LogisticRegression 학습/예측/평가
lr_clf.fit(X_train , y_train)
lr_pred = lr_clf.predict(X_test)
print('LogisticRegression 정확도: {0:.4f}'.format(accuracy_score(y_test, lr_pred)))
# Out:
# DecisionTreeClassifier 정확도: 0.8380
# RandomForestClassifier 정확도:0.8603
# LogisticRegression 정확도: 0.8436
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# - enumerate()
#  - https://blog.naver.com/jword_/223005344171

# %%
from sklearn.model_selection import KFold
def exec_kfold(clf, folds=5):
 # 폴드 세트를 5개인 KFold객체를 생성, 폴드 수만큼 예측결과 저장을 위한 리스트 객체 생성.
    kfold = KFold(n_splits=folds)
    scores = []
    
 
 # KFold 교차 검증 수행. 
    for iter_count , (train_index, test_index) in enumerate(kfold.split(X_titanic_df)):
     # X_titanic_df 데이터에서 교차 검증별로 학습과 검증 데이터를 가리키는 index 생성
     X_train, X_test = X_titanic_df.values[train_index], X_titanic_df.values[test_index]
     y_train, y_test = y_titanic_df.values[train_index], y_titanic_df.values[test_index]
 
     # Classifier 학습, 예측, 정확도 계산 
     clf.fit(X_train, y_train) 
     predictions = clf.predict(X_test)
     accuracy = accuracy_score(y_test, predictions)
     scores.append(accuracy)
     print("교차 검증 {0} 정확도: {1:.4f}".format(iter_count, accuracy)) 
 
  # 5개 fold에서의 평균 정확도 계산. 
    mean_score = np.mean(scores)
    print("평균 정확도: {0:.4f}\n".format(mean_score)) 

# exec_kfold 호출
exec_kfold(dt_clf)
exec_kfold(rf_clf)
exec_kfold(lr_clf)
# Out:
# 교차 검증 0 정확도: 0.7654
# 교차 검증 1 정확도: 0.7978
# 교차 검증 2 정확도: 0.7809
# 교차 검증 3 정확도: 0.7416
# 교차 검증 4 정확도: 0.8708
# 평균 정확도: 0.7913
#
# 교차 검증 0 정확도: 0.7989
# 교차 검증 1 정확도: 0.8146
# 교차 검증 2 정확도: 0.8315
# 교차 검증 3 정확도: 0.7640
# 교차 검증 4 정확도: 0.8315
# 평균 정확도: 0.8081
#
# 교차 검증 0 정확도: 0.8156
# 교차 검증 1 정확도: 0.7865
# 교차 검증 2 정확도: 0.7640
# 교차 검증 3 정확도: 0.7640
# 교차 검증 4 정확도: 0.8315
# 평균 정확도: 0.7923
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %%
from sklearn.model_selection import cross_val_score
def cvs(clf):
    scores = cross_val_score(clf, X_titanic_df , y_titanic_df , cv=5)
    for iter_count,accuracy in enumerate(scores):
        print("교차 검증 {0} 정확도: {1:.4f}".format(iter_count, accuracy))
    print("평균 정확도: {0:.4f}\n".format(np.mean(scores)))

cvs(dt_clf)
cvs(rf_clf)
cvs(lr_clf)
# Out:
# 교차 검증 0 정확도: 0.7765
# 교차 검증 1 정확도: 0.7865
# 교차 검증 2 정확도: 0.8202
# 교차 검증 3 정확도: 0.7584
# 교차 검증 4 정확도: 0.8427
# 평균 정확도: 0.7969
#
# 교차 검증 0 정확도: 0.7989
# 교차 검증 1 정확도: 0.7978
# 교차 검증 2 정확도: 0.8427
# 교차 검증 3 정확도: 0.7809
# 교차 검증 4 정확도: 0.8539
# 평균 정확도: 0.8148
#
# 교차 검증 0 정확도: 0.8045
# 교차 검증 1 정확도: 0.8034
# 교차 검증 2 정확도: 0.7640
# 교차 검증 3 정확도: 0.7640
# 교차 검증 4 정확도: 0.8090
# 평균 정확도: 0.7890
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# ...

# %% [markdown]
# - 하이퍼 파라미터
#   - https://blog.naver.com/unhiistu/223013405972

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'max_depth':[2,3,5,10],
 'min_samples_split':[2,3,5], 'min_samples_leaf':[1,5,8]}
grid_dclf = GridSearchCV(dt_clf , param_grid=parameters , scoring='accuracy' , cv=5)
grid_dclf.fit(X_train , y_train)
print('GridSearchCV 최적 하이퍼 파라미터 :',grid_dclf.best_params_)
print('GridSearchCV 최고 정확도: {0:.4f}'.format(grid_dclf.best_score_))
best_dclf = grid_dclf.best_estimator_
# GridSearchCV의 최적 하이퍼 파라미터로 학습된 Estimator로 예측 및 평가 수행. 
dpredictions = best_dclf.predict(X_test)
accuracy = accuracy_score(y_test , dpredictions)
print('테스트 세트에서의 DecisionTreeClassifier 정확도 : {0:.4f}'.format(accuracy))
# Out:
# GridSearchCV 최적 하이퍼 파라미터 : {'max_depth': 5, 'min_samples_leaf': 5, 'min_samples_split': 2}
# GridSearchCV 최고 정확도: 0.8161
# 테스트 세트에서의 DecisionTreeClassifier 정확도 : 0.8659
